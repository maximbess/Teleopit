# %%
import sys
print(sys.executable)
# Out:
# C:\Users\maxim\anaconda3\envs\teleopit\python.exe

# %%
# !python scripts/run/run_sim.py controller.policy_path=track.onnx input.bvh_file=data/sample_bvh/aiming1_subject1.bvh
# Out:
# Teleopit sim2sim
#
# State    MOCAP
# Input    BVH
# Viewers  sim2sim
# 17:59:42 {'steps': 608, 'root_height': 0.7687722371528997, 'policy_hz': 50.0, 'pd_hz': 200.0, 'decimation': 4, 'playback_stop': 0}

# %% [markdown]
# In file pyproject.toml: "qpsolvers[proxqp]" changed to "qpsolvers"
# Torch 2.13.0+cu126 is installed
