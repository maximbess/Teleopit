# %% [markdown]
# duplicate single dataset file into new folder: "teleopit_smoke_dataset"

# %% [raw]
# mkdir -p ~/teleopit_smoke_dataset/seed
#
# ln -s \
#   "/mnt/d/Westlake Internship/teleopit/data/datasets_precomputed/seed/shard_000.h5" \
#   ~/teleopit_smoke_dataset/seed/shard_000.h5

# %% [markdown]
# new dataset for benchmarking created with only pico_records there:
# $HOME/teleopit_benchmark_dataset

# %% [markdown]
# visualize dataset  (only not precomputed)  (run with administative role!!!)
# python scripts/view/view_dataset.py \
#   --dataset ./data/datasets/

# %% [markdown]
# train

# %% [raw]
# python train_mimic/scripts/train.py \
#   --motion_file "$HOME/teleopit_smoke_dataset" \
#   --num_envs 16 \
#   --max_iterations 1

# %% [markdown]
# use pretrained model
# python train_mimic/scripts/train.py  \
# --motion_file "$HOME/teleopit_smoke_dataset"  \
# --num_envs 512   \
# --max_iterations 100  \
# --resume "track.pt"

# %% [markdown]
# training with only shard_000.h5 with num_envs=32 & max_iterations=1000 took 44 minutes

# %% [markdown]
# playback
# {run} = 2026-07-21_17-27-18
# model_1 = model_{max_iterations}

# %% [raw]
# python train_mimic/scripts/play.py \
#     --checkpoint logs/rsl_rl/g1_general_tracking/{run}/model_{max_iterations}.pt \
#     --motion_file "$HOME/teleopit_smoke_dataset"

# %%
python train_mimic/scripts/play.py \
    --checkpoint logs/rsl_rl/g1_general_tracking/2026-07-21_18-16-33/model_1000.pt \
    --motion_file "$HOME/teleopit_smoke_dataset"

# %% [markdown]
# Visualize train results via TensorBoard
# tensorboard --logdir logs --port 6006

# %% [markdown]
# benchmark

# %%
python train_mimic/scripts/benchmark.py \  
    --checkpoint logs/rsl_rl/g1_general_tracking/2026-07-21_18-16-33/model_1000.pt \  
    --motion_file "$HOME/teleopit_smoke_dataset" \  
    --num_envs 1

# %%
python train_mimic/scripts/benchmark.py \
    --checkpoint logs/rsl_rl/g1_general_tracking/2026-07-21_18-16-33/model_1000.pt \
    --motion_file "$HOME/teleopit_smoke_dataset" \
    --num_envs 1  \
    --video \
    --video_length 600

# %% [markdown]
# настройка image:
# python 3.10 + torch 2.7.1 + cu11.8
# python -m pip install --no-cache-dir torch==2.7.1 torchvision==0.22.1 torchaudio==2.7.1 --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# task: use teleopit image + huangxiangru node + mount to huangxiangru folder then:
#
# first (env create):
# cd ..; cd maksimbessonov; cd myteleopit/Teleopit; conda create -n myteleopitenv python=3.10; conda activate myteleopitenv; pip install -e '.[train]'; python -c 'import train_mimic.tasks; print('\''training OK'\'')'
#
# second (train):
# cd ..; cd maksimbessonov; cd myteleopit/Teleopit; conda activate myteleopitenv; pip install -e '.[train]'; python -c 'import train_mimic.tasks; print('\''training OK'\'')'; python train_mimic/scripts/train.py --gpu_ids 0 1 2 3 --num_envs 1024 --max_iterations 20000 --motion_file data/datasets_precomputed
